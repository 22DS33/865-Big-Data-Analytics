# %%
from pyspark.sql.functions import lit

# Load in one of the tables
df = spark.sql("select * from default.reviews_train")

# Take a sample (useful for code development purposes)
df = df.sample(False, 0.15, seed=0)

df = df.cache()

print((df.count(), len(df.columns)))
# Out:
# (470645, 11)

# %%
df.printSchema()
# Out:
# root
#  |-- reviewID: integer (nullable = true)
#  |-- overall: double (nullable = true)
#  |-- verified: boolean (nullable = true)
#  |-- reviewTime: string (nullable = true)
#  |-- reviewerID: string (nullable = true)
#  |-- asin: string (nullable = true)
#  |-- reviewerName: string (nullable = true)
#  |-- reviewText: string (nullable = true)
#  |-- summary: string (nullable = true)
#  |-- unixReviewTime: integer (nullable = true)
#  |-- label: integer (nullable = true)

# %%
# Let's look at some quick summary statistics
df.describe().show()
# Out:
# +-------+------------------+------------------+----------+--------------------+--------------------+--------------+--------------------+--------------------+--------------------+-------------------+
# |summary|          reviewID|           overall|reviewTime|          reviewerID|                asin|  reviewerName|          reviewText|             summary|      unixReviewTime|              label|
# +-------+------------------+------------------+----------+--------------------+--------------------+--------------+--------------------+--------------------+--------------------+-------------------+
# |  count|            470645|            470645|    470645|              470645|              470645|        470612|              470645|              470585|              470645|             470645|
# |   mean|1569466.7378533715| 4.316557065303997|      null|                null| 4.295464796096894E7|           NaN|  179.13333333333333|           50819.075|1.3922720677266304E9|0.17867819694249382|
# | stddev| 906251.4849832825|1.1272496217800216|      null|                null|2.5215717528552324E8|           NaN|   470.0926757667298|  223651.24071703784|1.0328280239631511E8|0.38308303367750296|
# |    min|                 3|               1.0|01 1, 1998|A0010876CNE3ILIM9HV0|          0000230022|              |  Price Point: 4....|  BUT THEN IT BREAKS|           843004800|                  0|
# |    max|           3138701|               5.0|12 9, 2017|       AZZYW4YOE1B6E|          B01HIZGKOE|~~MomOf2Boys~~|~~THE AWAKENING~~...|~~less predictabl...|          1537660800|                  1|
# +-------+------------------+------------------+----------+--------------------+--------------------+--------------+--------------------+--------------------+--------------------+-------------------+

# %%
from pyspark.sql.functions import col
display(df.groupBy("overall").count().orderBy("overall"))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>overall</th><th>count</th></tr></thead><tbody><tr><td>1.0</td><td>24375</td></tr><tr><td>2.0</td><td>20812</td></tr><tr><td>3.0</td><td>39424</td></tr><tr><td>4.0</td><td>82875</td></tr><tr><td>5.0</td><td>303159</td></tr></tbody></table></div>

# %%
# The most common product IDs
display(df.groupBy("asin").count().orderBy(col("count").desc()).head(50))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>asin</th><th>count</th></tr></thead><tbody><tr><td>0007420412</td><td>2681</td></tr><tr><td>000711835X</td><td>2468</td></tr><tr><td>0007548672</td><td>2171</td></tr><tr><td>0007350899</td><td>1101</td></tr><tr><td>0007444117</td><td>1076</td></tr><tr><td>B000YGEVMI</td><td>958</td></tr><tr><td>0007378033</td><td>855</td></tr><tr><td>B0015TMHSI</td><td>782</td></tr><tr><td>0007384289</td><td>682</td></tr><tr><td>006017322X</td><td>677</td></tr><tr><td>0007350783</td><td>640</td></tr><tr><td>0002247399</td><td>635</td></tr><tr><td>0007141424</td><td>597</td></tr><tr><td>0008220565</td><td>592</td></tr><tr><td>B0014CX87U</td><td>583</td></tr><tr><td>0007155662</td><td>581</td></tr><tr><td>0007271239</td><td>540</td></tr><tr><td>0060740221</td><td>535</td></tr><tr><td>B00164M9XA</td><td>528</td></tr><tr><td>B0015NC4H8</td><td>507</td></tr><tr><td>000755236X</td><td>479</td></tr><tr><td>B0014QS1XC</td><td>444</td></tr><tr><td>B000BWZ7QO</td><td>439</td></tr><tr><td>B002S52ZDU</td><td>437</td></tr><tr><td>0007368658</td><td>429</td></tr><tr><td>0030565073</td><td>426</td></tr><tr><td>0002247437</td><td>419</td></tr><tr><td>0008118922</td><td>417</td></tr><tr><td>B000ZK5UT6</td><td>415</td></tr><tr><td>B000VZRZE8</td><td>413</td></tr><tr><td>B000M8YMEU</td><td>411</td></tr><tr><td>B0017XHSC2</td><td>408</td></tr><tr><td>B0012LOQUQ</td><td>404</td></tr><tr><td>0001048767</td><td>401</td></tr><tr><td>B000VENLF6</td><td>401</td></tr><tr><td>0007447868</td><td>390</td></tr><tr><td>0060558121</td><td>386</td></tr><tr><td>B000GWG0T2</td><td>381</td></tr><tr><td>B002KAPNA0</td><td>371</td></tr><tr><td>0061257095</td><td>370</td></tr><tr><td>B0016P7EUW</td><td>370</td></tr><tr><td>0061351415</td><td>367</td></tr><tr><td>B00008UA3Y</td><td>367</td></tr><tr><td>0001844423</td><td>351</td></tr><tr><td>B000RL1WNQ</td><td>347</td></tr><tr><td>0008102147</td><td>346</td></tr><tr><td>0007173156</td><td>345</td></tr><tr><td>B001892AX2</td><td>345</td></tr><tr><td>006019832X</td><td>344</td></tr><tr><td>B000N4WN08</td><td>342</td></tr></tbody></table></div>

# %%
display(df.groupBy("label").count().orderBy("label"))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>label</th><th>count</th></tr></thead><tbody><tr><td>0</td><td>386551</td></tr><tr><td>1</td><td>84094</td></tr></tbody></table></div>

# %%
from pyspark.ml import Pipeline
from pyspark.ml.feature import RegexTokenizer, StopWordsRemover
from pyspark.sql import functions as f

# We'll tokenize the text using a simple RegexTokenizer
tokenizer = RegexTokenizer(inputCol="reviewText", outputCol="words", pattern="\\W")

# Remove standard Stopwords
stopwordsRemover = StopWordsRemover(inputCol="words", outputCol="filtered")

pipeline = Pipeline(stages=[tokenizer, stopwordsRemover])

pipelineFit = pipeline.fit(df)
df = pipelineFit.transform(df)

# %%
counts = df.select(f.explode('filtered').alias('col')).groupBy('col').count().sort(f.desc('count')).collect()
display(counts)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>col</th><th>count</th></tr></thead><tbody><tr><td>one</td><td>167556</td></tr><tr><td>book</td><td>165187</td></tr><tr><td>game</td><td>141451</td></tr><tr><td>great</td><td>131777</td></tr><tr><td>like</td><td>129426</td></tr><tr><td>good</td><td>106801</td></tr><tr><td>well</td><td>94366</td></tr><tr><td>read</td><td>89533</td></tr><tr><td>time</td><td>83685</td></tr><tr><td>get</td><td>80686</td></tr><tr><td>love</td><td>80241</td></tr><tr><td>use</td><td>77622</td></tr><tr><td>really</td><td>76224</td></tr><tr><td>much</td><td>71183</td></tr><tr><td>story</td><td>68721</td></tr><tr><td>also</td><td>60901</td></tr><tr><td>first</td><td>58474</td></tr><tr><td>even</td><td>57480</td></tr><tr><td>little</td><td>53545</td></tr><tr><td>easy</td><td>48975</td></tr><tr><td>way</td><td>46377</td></tr><tr><td>make</td><td>45350</td></tr><tr><td>ve</td><td>43846</td></tr><t