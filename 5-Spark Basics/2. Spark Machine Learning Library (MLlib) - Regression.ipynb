# %% [markdown]
# # What is Spark MLlib?
#
# Apache Spark’s Machine Learning Library (MLlib) is designed for simplicity, scalability, and easy integration with other tools. With the scalability, language compatibility, and speed of Spark, data scientists can focus on their data problems and models instead of solving the complexities surrounding distributed data (such as infrastructure, configurations, and so on). Built on top of Spark, MLlib is a scalable machine learning library consisting of common learning algorithms and utilities, including classification, regression, clustering, collaborative filtering, dimensionality reduction, and underlying optimization primitives. Spark MLLib seamlessly integrates with other Spark components such as Spark SQL, Spark Streaming, and DataFrames and is installed in the Databricks runtime. The library is usable in Java, Scala, and Python as part of Spark applications, so that you can include it in complete workflows. MLlib allows for preprocessing, munging, training of models, and making predictions at scale on data. You can even use models trained in MLlib to make predictions in Structured Streaming. Spark provides a sophisticated machine learning API for performing a variety of machine learning tasks, from classification to regression, clustering to deep learning.
#
# (https://databricks.com/glossary/what-is-machine-learning-library)

# %% [markdown]
# # Loading Dataset

# %%
data = spark.sql('SELECT * FROM boston')
data.display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>crim</th><th>zn</th><th>indus</th><th>chas</th><th>nox</th><th>rm</th><th>age</th><th>dis</th><th>rad</th><th>tax</th><th>ptratio</th><th>black</th><th>lstat</th><th>medv</th></tr></thead><tbody><tr><td>0.00632</td><td>18.0</td><td>2.31</td><td>0</td><td>0.538</td><td>6.575</td><td>65.2</td><td>4.09</td><td>1</td><td>296</td><td>15.3</td><td>396.9</td><td>4.98</td><td>24.0</td></tr><tr><td>0.02731</td><td>0.0</td><td>7.07</td><td>0</td><td>0.469</td><td>6.421</td><td>78.9</td><td>4.9671</td><td>2</td><td>242</td><td>17.8</td><td>396.9</td><td>9.14</td><td>21.6</td></tr><tr><td>0.02729</td><td>0.0</td><td>7.07</td><td>0</td><td>0.469</td><td>7.185</td><td>61.1</td><td>4.9671</td><td>2</td><td>242</td><td>17.8</td><td>392.83</td><td>4.03</td><td>34.7</td></tr><tr><td>0.03237</td><td>0.0</td><td>2.18</td><td>0</td><td>0.458</td><td>6.998</td><td>45.8</td><td>6.0622</td><td>3</td><td>222</td><td>18.7</td><td>394.63</td><td>2.94</td><td>33.4</td></tr><tr><td>0.06905</td><td>0.0</td><td>2.18</td><td>0</td><td>0.458</td><td>7.147</td><td>54.2</td><td>6.0622</td><td>3</td><td>222</td><td>18.7</td><td>396.9</td><td>5.33</td><td>36.2</td></tr><tr><td>0.02985</td><td>0.0</td><td>2.18</td><td>0</td><td>0.458</td><td>6.43</td><td>58.7</td><td>6.0622</td><td>3</td><td>222</td><td>18.7</td><td>394.12</td><td>5.21</td><td>28.7</td></tr><tr><td>0.08829</td><td>12.5</td><td>7.87</td><td>0</td><td>0.524</td><td>6.012</td><td>66.6</td><td>5.5605</td><td>5</td><td>311</td><td>15.2</td><td>395.6</td><td>12.43</td><td>22.9</td></tr><tr><td>0.14455</td><td>12.5</td><td>7.87</td><td>0</td><td>0.524</td><td>6.172</td><td>96.1</td><td>5.9505</td><td>5</td><td>311</td><td>15.2</td><td>396.9</td><td>19.15</td><td>27.1</td></tr><tr><td>0.21124</td><td>12.5</td><td>7.87</td><td>0</td><td>0.524</td><td>5.631</td><td>100.0</td><td>6.0821</td><td>5</td><td>311</td><td>15.2</td><td>386.63</td><td>29.93</td><td>16.5</td></tr><tr><td>0.17004</td><td>12.5</td><td>7.87</td><td>0</td><td>0.524</td><td>6.004</td><td>85.9</td><td>6.5921</td><td>5</td><td>311</td><td>15.2</td><td>386.71</td><td>17.1</td><td>18.9</td></tr><tr><td>0.22489</td><td>12.5</td><td>7.87</td><td>0</td><td>0.524</td><td>6.377</td><td>94.3</td><td>6.3467</td><td>5</td><td>311</td><td>15.2</td><td>392.52</td><td>20.45</td><td>15.0</td></tr><tr><td>0.11747</td><td>12.5</td><td>7.87</td><td>0</td><td>0.524</td><td>6.009</td><td>82.9</td><td>6.2267</td><td>5</td><td>311</td><td>15.2</td><td>396.9</td><td>13.27</td><td>18.9</td></tr><tr><td>0.09378</td><td>12.5</td><td>7.87</td><td>0</td><td>0.524</td><td>5.889</td><td>39.0</td><td>5.4509</td><td>5</td><td>311</td><td>15.2</td><td>390.5</td><td>15.71</td><td>21.7</td></tr><tr><td>0.62976</td><td>0.0</td><td>8.14</td><td>0</td><td>0.538</td><td>5.949</td><td>61.8</td><td>4.7075</td><td>4</td><td>307</td><td>21.0</td><td>396.9</td><td>8.26</td><td>20.4</td></tr><tr><td>0.63796</td><td>0.0</td><td>8.14</td><td>0</td><td>0.538</td><td>6.096</td><td>84.5</td><td>4.4619</td><td>4</td><td>307</td><td>21.0</td><td>380.02</td><td>10.26</td><td>18.2</td></tr><tr><td>0.62739</td><td>0.0</td><td>8.14</td><td>0</td><td>0.538</td><td>5.834</td><td>56.5</td><td>4.4986</td><td>4</td><td>307</td><td>21.0</td><td>395.62</td><td>8.47</td><td>19.9</td></tr><tr><td>1.05393</td><td>0.0</td><td>8.14</td><td>0</td><td>0.538</td><td>5.935</td><td>29.3</td><td>4.4986</td><td>4</td><td>307</td><td>21.0</td><td>386.85</td><td>6.58</td><td>23.1</td></tr><tr><td>0.7842</td><td>0.0</td><td>8.14</td><td>0</td><td>0.538</td><td>5.99</td><td>81.7</td><td>4.2579</td><td>4</td><td>307</td><td>21.0</td><td>386.75</td><td>14.67</td><td>17.5</td></tr><tr><td>0.80271</td><td>0.0</td><td>8.14</td><td>0</td><td>0.538</td><td>5.456</td><td>36.6</td><td>3.7965</td><td>4</td><td>307</td><td>21.0</td><td>288.99</td><td>11.69</td><td>20.2</td></tr><tr><td>0.7258</td><td>0.0</td><t ...

# %%
data.printSchema()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">root
# -- crim: double (nullable = true)
# -- zn: double (nullable = true)
# -- indus: double (nullable = true)
# -- chas: integer (nullable = true)
# -- nox: double (nullable = true)
# -- rm: double (nullable = true)
# -- age: double (nullable = true)
# -- dis: double (nullable = true)
# -- rad: integer (nullable = true)
# -- tax: integer (nullable = true)
# -- ptratio: double (nullable = true)
# -- black: double (nullable = true)
# -- lstat: double (nullable = true)
# -- medv: double (nullable = true)
#
# </div>

# %% [markdown]
# # Transform the Data to work with MLlib

# %%
from pyspark.ml.linalg import Vectors
from pyspark.ml.feature import VectorAssembler
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
data.columns
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[4]: [&#39;crim&#39;,
#  &#39;zn&#39;,
#  &#39;indus&#39;,
#  &#39;chas&#39;,
#  &#39;nox&#39;,
#  &#39;rm&#39;,
#  &#39;age&#39;,
#  &#39;dis&#39;,
#  &#39;rad&#39;,
#  &#39;tax&#39;,
#  &#39;ptratio&#39;,
#  &#39;black&#39;,
#  &#39;lstat&#39;,
#  &#39;medv&#39;]</div>

# %%
assembler = VectorAssembler(inputCols=['crim', 'zn', 'indus', 'chas','nox','rm','age','dis','rad','tax','ptratio','black','lstat'],
                            outputCol='features')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
output = assembler.transform(data)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
output.display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>crim</th><th>zn</th><th>indus</th><th>chas</th><th>nox</th><th>rm</th><th>age</th><th>dis</th><th>rad</th><th>tax</th><th>ptratio</th><th>black</th><th>lstat</th><th>medv</th><th>features</th></tr></thead><tbody><tr><td>0.00632</td><td>18.0</td><td>2.31</td><td>0</td><td>0.538</td><td>6.575</td><td>65.2</td><td>4.09</td><td>1</td><td>296</td><td>15.3</td><td>396.9</td><td>4.98</td><td>24.0</td><td>Map(vectorType -> dense, length -> 13, values -> List(0.00632, 18.0, 2.31, 0.0, 0.538, 6.575, 65.2, 4.09, 1.0, 296.0, 15.3, 396.9, 4.98))</td></tr><tr><td>0.02731</td><td>0.0</td><td>7.07</td><td>0</td><td>0.469</td><td>6.421</td><td>78.9</td><td>4.9671</td><td>2</td><td>242</td><td>17.8</td><td>396.9</td><td>9.14</td><td>21.6</td><td>Map(vectorType -> dense, length -> 13, values -> List(0.02731, 0.0, 7.07, 0.0, 0.469, 6.421, 78.9, 4.9671, 2.0, 242.0, 17.8, 396.9, 9.14))</td></tr><tr><td>0.02729</td><td>0.0</td><td>7.07</td><td>0</td><td>0.469</td><td>7.185</td><td>61.1</td><td>4.9671</td><td>2</td><td>242</td><td>17.8</td><td>392.83</td><td>4.03</td><td>34.7</td><td>Map(vectorType -> dense, length -> 13, values -> List(0.02729, 0.0, 7.07, 0.0, 0.469, 7.185, 61.1, 4.9671, 2.0, 242.0, 17.8, 392.83, 4.03))</td></tr><tr><td>0.03237</td><td>0.0</td><td>2.18</td><td>0</td><td>0.458</td><td>6.998</td><td>45.8</td><td>6.0622</td><td>3</td><td>222</td><td>18.7</td><td>394.63</td><td>2.94</td><td>33.4</td><td>Map(vectorType -> dense, length -> 13, values -> List(0.03237, 0.0, 2.18, 0.0, 0.458, 6.998, 45.8, 6.0622, 3.0, 222.0, 18.7, 394.63, 2.94))</td></tr><tr><td>0.06905</td><td>0.0</td><td>2.18</td><td>0</td><td>0.458</td><td>7.147</td><td>54.2</td><td>6.0622</td><td>3</td><td>222</td><td>18.7</td><td>396.9</td><td>5.33</td><td>36.2</td><td>Map(vectorType -> dense, length -> 13, values -> List(0.06905, 0.0, 2.18, 0.0, 0.458, 7.147, 54.2, 6.0622, 3.0, 222.0, 18.7, 396.9, 5.33))</td></tr><tr><td>0.02985</td><td>0.0</td><td>2.18</td><td>0</td><td>0.458</td><td>6.43</td><td>58.7</td><td>6.0622</td><td>3</td><td>222</td><td>18.7</td><td>394.12</td><td>5.21</td><td>28.7</td><td>Map(vectorType -> dense, length -> 13, values -> List(0.02985, 0.0, 2.18, 0.0, 0.458, 6.43, 58.7, 6.0622, 3.0, 222.0, 18.7, 394.12, 5.21))</td></tr><tr><td>0.08829</td><td>12.5</td><td>7.87</td><td>0</td><td>0.524</td><td>6.012</td><td>66.6</td><td>5.5605</td><td>5</td><td>311</td><td>15.2</td><td>395.6</td><td>12.43</td><td>22.9</td><td>Map(vectorType -> dense, length -> 13, values -> List(0.08829, 12.5, 7.87, 0.0, 0.524, 6.012, 66.6, 5.5605, 5.0, 311.0, 15.2, 395.6, 12.43))</td></tr><tr><td>0.14455</td><td>12.5</td><td>7.87</td><td>0</td><td>0.524</td><td>6.172</td><td>96.1</td><td>5.9505</td><td>5</td><td>311</td><td>15.2</td><td>396.9</td><td>19.15</td><td>27.1</td><td>Map(vectorType -> dense, length -> 13, values -> List(0.14455, 12.5, 7.87, 0.0, 0.524, 6.172, 96.1, 5.9505, 5.0, 311.0, 15.2, 396.9, 19.15))</td></tr><tr><td>0.21124</td><td>12.5</td><td>7.87</td><td>0</td><td>0.524</td><td>5.631</td><td>100.0</td><td>6.0821</td><td>5</td><td>311</td><td>15.2</td><td>386.63</td><td>29.93</td><td>16.5</td><td>Map(vectorType -> dense, length -> 13, values -> List(0.21124, 12.5, 7.87, 0.0, 0.524, 5.631, 100.0, 6.0821, 5.0, 311.0, 15.2, 386.63, 29.93))</td></tr><tr><td>0.17004</td><td>12.5</td><td>7.87</td><td>0</td><td>0.524</td><td>6.004</td><td>85.9</td><td>6.5921</td><td>5</td><td>311</td><td>15.2</td><td>386.71</td><td>17.1</td><td>18.9</td><td>Map(vectorType -> dense, length -> 13, values -> List(0.17004, 12.5, 7.87, 0.0, 0.524, 6.004, 85.9, 6.5921, 5.0, 311.0, 15.2, 386.71, 17.1))</td></tr><tr><td>0.22489</td><td>12.5</td><td>7.87</td><td>0</td><td>0.524</td><td>6.377</td><td>94.3</td><td>6.3467</td><td>5</td><td>311</td><td>15.2</td><td>392.52</td><td>20.45</td><td>15.0</td><td>Map(vectorType -> dense, length -> 13, values -> List(0.22489, 12.5, 7.87, ...

# %%
final_data = output.select('features', 'medv')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
final_data.display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>features</th><th>medv</th></tr></thead><tbody><tr><td>Map(vectorType -> dense, length -> 13, values -> List(0.00632, 18.0, 2.31, 0.0, 0.538, 6.575, 65.2, 4.09, 1.0, 296.0, 15.3, 396.9, 4.98))</td><td>24.0</td></tr><tr><td>Map(vectorType -> dense, length -> 13, values -> List(0.02731, 0.0, 7.07, 0.0, 0.469, 6.421, 78.9, 4.9671, 2.0, 242.0, 17.8, 396.9, 9.14))</td><td>21.6</td></tr><tr><td>Map(vectorType -> dense, length -> 13, values -> List(0.02729, 0.0, 7.07, 0.0, 0.469, 7.185, 61.1, 4.9671, 2.0, 242.0, 17.8, 392.83, 4.03))</td><td>34.7</td></tr><tr><td>Map(vectorType -> dense, length -> 13, values -> List(0.03237, 0.0, 2.18, 0.0, 0.458, 6.998, 45.8, 6.0622, 3.0, 222.0, 18.7, 394.63, 2.94))</td><td>33.4</td></tr><tr><td>Map(vectorType -> dense, length -> 13, values -> List(0.06905, 0.0, 2.18, 0.0, 0.458, 7.147, 54.2, 6.0622, 3.0, 222.0, 18.7, 396.9, 5.33))</td><td>36.2</td></tr><tr><td>Map(vectorType -> dense, length -> 13, values -> List(0.02985, 0.0, 2.18, 0.0, 0.458, 6.43, 58.7, 6.0622, 3.0, 222.0, 18.7, 394.12, 5.21))</td><td>28.7</td></tr><tr><td>Map(vectorType -> dense, length -> 13, values -> List(0.08829, 12.5, 7.87, 0.0, 0.524, 6.012, 66.6, 5.5605, 5.0, 311.0, 15.2, 395.6, 12.43))</td><td>22.9</td></tr><tr><td>Map(vectorType -> dense, length -> 13, values -> List(0.14455, 12.5, 7.87, 0.0, 0.524, 6.172, 96.1, 5.9505, 5.0, 311.0, 15.2, 396.9, 19.15))</td><td>27.1</td></tr><tr><td>Map(vectorType -> dense, length -> 13, values -> List(0.21124, 12.5, 7.87, 0.0, 0.524, 5.631, 100.0, 6.0821, 5.0, 311.0, 15.2, 386.63, 29.93))</td><td>16.5</td></tr><tr><td>Map(vectorType -> dense, length -> 13, values -> List(0.17004, 12.5, 7.87, 0.0, 0.524, 6.004, 85.9, 6.5921, 5.0, 311.0, 15.2, 386.71, 17.1))</td><td>18.9</td></tr><tr><td>Map(vectorType -> dense, length -> 13, values -> List(0.22489, 12.5, 7.87, 0.0, 0.524, 6.377, 94.3, 6.3467, 5.0, 311.0, 15.2, 392.52, 20.45))</td><td>15.0</td></tr><tr><td>Map(vectorType -> dense, length -> 13, values -> List(0.11747, 12.5, 7.87, 0.0, 0.524, 6.009, 82.9, 6.2267, 5.0, 311.0, 15.2, 396.9, 13.27))</td><td>18.9</td></tr><tr><td>Map(vectorType -> dense, length -> 13, values -> List(0.09378, 12.5, 7.87, 0.0, 0.524, 5.889, 39.0, 5.4509, 5.0, 311.0, 15.2, 390.5, 15.71))</td><td>21.7</td></tr><tr><td>Map(vectorType -> dense, length -> 13, values -> List(0.62976, 0.0, 8.14, 0.0, 0.538, 5.949, 61.8, 4.7075, 4.0, 307.0, 21.0, 396.9, 8.26))</td><td>20.4</td></tr><tr><td>Map(vectorType -> dense, length -> 13, values -> List(0.63796, 0.0, 8.14, 0.0, 0.538, 6.096, 84.5, 4.4619, 4.0, 307.0, 21.0, 380.02, 10.26))</td><td>18.2</td></tr><tr><td>Map(vectorType -> dense, length -> 13, values -> List(0.62739, 0.0, 8.14, 0.0, 0.538, 5.834, 56.5, 4.4986, 4.0, 307.0, 21.0, 395.62, 8.47))</td><td>19.9</td></tr><tr><td>Map(vectorType -> dense, length -> 13, values -> List(1.05393, 0.0, 8.14, 0.0, 0.538, 5.935, 29.3, 4.4986, 4.0, 307.0, 21.0, 386.85, 6.58))</td><td>23.1</td></tr><tr><td>Map(vectorType -> dense, length -> 13, values -> List(0.7842, 0.0, 8.14, 0.0, 0.538, 5.99, 81.7, 4.2579, 4.0, 307.0, 21.0, 386.75, 14.67))</td><td>17.5</td></tr><tr><td>Map(vectorType -> dense, length -> 13, values -> List(0.80271, 0.0, 8.14, 0.0, 0.538, 5.456, 36.6, 3.7965, 4.0, 307.0, 21.0, 288.99, 11.69))</td><td>20.2</td></tr><tr><td>Map(vectorType -> dense, length -> 13, values -> List(0.7258, 0.0, 8.14, 0.0, 0.538, 5.727, 69.5, 3.7965, 4.0, 307.0, 21.0, 390.95, 11.28))</td><td>18.2</td></tr><tr><td>Map(vectorType -> dense, length -> 13, values -> List(1.25179, 0.0, 8.14, 0.0, 0.538, 5.57, 98.1, 3.7979, 4.0, 307.0, 21.0, 376.57, 21.02))</td><td>13.6</td></tr><tr><td>Map(vectorType -> dense, length -> 13, values -> List(0.85204, 0.0, 8.14, 0.0, 0.538, 5.965, 89.2, 4.0123, 4.0, 307.0, 21.0, 392.53, 13.83))</td><td>19.6</td></tr><tr><td>Map(vectorType -> dense, length -> 13, values -> List(1.23247, 0.0, 8.14, 0.0, 0. ...

# %% [markdown]
# # Train Test Split

# %%
train, test = final_data.randomSplit([0.7,0.3])
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
train.describe().display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>summary</th><th>medv</th></tr></thead><tbody><tr><td>count</td><td>347</td></tr><tr><td>mean</td><td>22.266282420749295</td></tr><tr><td>stddev</td><td>9.08488478272475</td></tr><tr><td>min</td><td>5.0</td></tr><tr><td>max</td><td>50.0</td></tr></tbody></table></div>

# %%
test.describe().display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>summary</th><th>medv</th></tr></thead><tbody><tr><td>count</td><td>159</td></tr><tr><td>mean</td><td>23.11446540880503</td></tr><tr><td>stddev</td><td>9.44025072396866</td></tr><tr><td>min</td><td>5.0</td></tr><tr><td>max</td><td>50.0</td></tr></tbody></table></div>

# %% [markdown]
# # Linear Regression

# %%
from pyspark.ml.regression import LinearRegression
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
lr = LinearRegression(labelCol='medv')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
lr_fit = lr.fit(train)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# # Model Evaluation

# %%
# calling evaluate function on fitted model
test_results = lr_fit.evaluate(test)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# Root Mean Squared Error (RMSE) on test set
test_results.rootMeanSquaredError
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[17]: 5.527429409423636</div>

# %%
# R2 on test set
test_results.r2
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[18]: 0.6549997661613198</div>

# %%
# Mean Absolute Error (MAE) on test set
test_results.meanAbsoluteError
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[19]: 3.8633544344793673</div>

# %%
# Mean Squared Error (MSE) on test set
test_results.meanSquaredError
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[20]
774856534</td></tr><tr><td>4.298743010110936</td></tr><tr><td>-2.432128938261311</td></tr><tr><td>12.432465731951378</td></tr><tr><td>-1.8918215209684917</td></tr><tr><td>-0.3436578552511165</td></tr><tr><td>0.6519805246025001</td></tr><tr><td>-1.73404981977016</td></tr><tr><td>-6.0338457148666365</td></tr><tr><td>-1.4000160581564671</td></tr><tr><td>9.71668557780498</td></tr><tr><td>5.622565156024656</td></tr><tr><td>8.939554342282442</td></tr><tr><td>6.1304017358636855</td></tr><tr><td>-5.456850383735819</td></tr><tr><td>0.4390457885559904</td></tr><tr><td>0.6089385835008834</td></tr><tr><td>-0.7840561768309939</td></tr><tr><td>-0.46942216922106006</td></tr><tr><td>-5.1397565299340044</td></tr><tr><td>-0.6770429247058125</td></tr><tr><td>-4.641301633496003</td></tr><tr><td>4.424042288488419</td></tr><tr><td>-3.7567140333669826</td></tr><tr><td>0.15968652832535213</td></tr><tr><td>-4.4763945125371905</td></tr><tr><td>8.259860050608054</td></tr><tr><td>-4.2812753709876326</td></tr><tr><td>-3.969581919327581</td></tr><tr><td>4.563433319894429</td></tr><tr><td>-2.5238298163344908</td></tr><tr><td>13.306518008848485</td></tr><tr><td>0.4955 ...

# %% [markdown]
# # Scoring on new data

# %%
# lets create a new data by removing target col from test set
new_data = test.select('features')
new_data.display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>features</th></tr></thead><tbody><tr><td>Map(vectorType -> dense, length -> 13, values -> List(0.01301, 35.0, 1.52, 0.0, 0.442, 7.241, 49.3, 7.0379, 1.0, 284.0, 15.5, 394.74, 5.49))</td></tr><tr><td>Map(vectorType -> dense, length -> 13, values -> List(0.01538, 90.0, 3.75, 0.0, 0.394, 7.454, 34.2, 6.3361, 3.0, 244.0, 15.9, 386.34, 3.11))</td></tr><tr><td>Map(vectorType -> dense, length -> 13, values -> List(0.01965, 80.0, 1.76, 0.0, 0.385, 6.23, 31.5, 9.0892, 1.0, 241.0, 18.2, 341.6, 12.93))</td></tr><tr><td>Map(vectorType -> dense, length -> 13, values -> List(0.02729, 0.0, 7.07, 0.0, 0.469, 7.185, 61.1, 4.9671, 2.0, 242.0, 17.8, 392.83, 4.03))</td></tr><tr><td>Map(vectorType -> dense, length -> 13, values -> List(0.02763, 75.0, 2.95, 0.0, 0.428, 6.595, 21.8, 5.4011, 3.0, 252.0, 18.3, 395.63, 4.32))</td></tr><tr><td>Map(vectorType -> dense, length -> 13, values -> List(0.03049, 55.0, 3.78, 0.0, 0.484, 6.874, 28.1, 6.4654, 5.0, 370.0, 17.6, 387.97, 4.61))</td></tr><tr><td>Map(vectorType -> dense, length -> 13, values -> List(0.03306, 0.0, 5.19, 0.0, 0.515, 6.059, 37.3, 4.8122, 5.0, 224.0, 20.2, 396.14, 8.51))</td></tr><tr><td>Map(vectorType -> dense, length -> 13, values -> List(0.03466, 35.0, 6.06, 0.0, 0.4379, 6.031, 23.3, 6.6407, 1.0, 304.0, 16.9, 362.25, 7.83))</td></tr><tr><td>Map(vectorType -> dense, length -> 13, values -> List(0.03537, 34.0, 6.09, 0.0, 0.433, 6.59, 40.4, 5.4917, 7.0, 329.0, 16.1, 395.75, 9.5))</td></tr><tr><td>Map(vectorType -> dense, length -> 13, values -> List(0.03584, 80.0, 3.37, 0.0, 0.398, 6.29, 17.8, 6.6115, 4.0, 337.0, 16.1, 396.9, 4.67))</td></tr><tr><td>Map(vectorType -> dense, length -> 13, values -> List(0.03738, 0.0, 5.19, 0.0, 0.515, 6.31, 38.5, 6.4584, 5.0, 224.0, 20.2, 389.4, 6.75))</td></tr><tr><td>Map(vectorType -> dense, length -> 13, values -> List(0.03768, 80.0, 1.52, 0.0, 0.404, 7.274, 38.3, 7.309, 2.0, 329.0, 12.6, 392.2, 6.62))</td></tr><tr><td>Map(vectorType -> dense, length -> 13, values -> List(0.
td></tr><tr><td>Map(vectorType -> dense, length -> 13, values -> List(0.03584, 80.0, 3.37, 0.0, 0.398, 6.29, 17.8, 6.6115, 4.0, 337.0, 16.1, 396.9, 4.67))</td><td>30.233719622699944</td></tr><tr><td>Map(vectorType -> dense, length -> 13, values -> List(0.03738, 0.0, 5.19, 0.0, 0.515, 6.31, 38.5, 6.4584, 5.0, 224.0, 20.2, 389.4, 6.75))</td><td>21.707780278176713</td></tr><tr><td>Map(vectorType -> dense, length -> 13, values -> List(0.03768, 80.0, 1.52, 0.0, 0.404, 7.274, 38.3, 7.309, 2.0, 329.0, 12.6, 392.2, 6.62))</td><td>34.78581599011168</td></tr><tr><td>Map(vectorType -> dense, length -> 13, values -> List(0.03961, 0.0, 5.19, 0.0, 0.515, 6.037, 34.5, 5.9853, 5.0, 224.0, 20.2, 396.9, 8.01))</td><td>20.676494235873847</td></tr><tr><td>Map(vectorType -> dense, length -> 13, values -> List(0.04113, 25.0, 4.86, 0.0, 0.426, 6.727, 33.5, 5.4007, 4.0, 281.0, 19.0, 396.9, 5.29))</td><td>28.449441900632337</td></tr><tr><td>Map(vectorType -> dense, length -> 13, values -> List(0.04294, 28.0, 15.04, 0.0, 0.464, 6.249, 77.3, 3.615, 4.0, 270.0, 18.2, 396.9, 10.59))</td><td>26.845739635865495</td></tr><tr><td>Map(vectorType -> dense, length -> 13, values -> List(0.04417, 70.0, 2.24, 0.0, 0.4, 6.871, 47.4, 7.8278, 5.0, 358.0, 14.8, 390.86, 6.07))</td><td>30.89809087042977</td></tr><tr><td>Map(vectorType -> dense, length -> 13, values -> List(0.0459, 52.5, 5.32, 0.0, 0.405, 6.315, 45.6, 7.3172, 6.0, 293.0, 16.6, 396.9, 7.6))</td><td>27.133752028310486</td></tr><tr><td>Map(vectorType -> dense, length -> 13, values -> List(0.04666, 80.0, 1.52, 0.0, 0.404, 7.107, 36.6, 7.309, 2.0, 329.0, 12.6, 354.31, 8.61))</td><td>32.58576522972999</td></tr><tr><td>Map(vectorType -> dense, length -> 13, values -> List(0.04932, 33.0, 2.18, 0.0, 0.472, 6.849, 70.3, 3.1827, 7.0, 222.0, 18.4, 396.9, 7.53))</td><td>32.90070186942087</td></tr><tr><td>Map(vectorType -> dense, length -> 13, values -> List(0.05023, 35.0, 6.06, 0.0, 0.4379, 5.706, 28.4, 6.6407, 1.0, 304.0, 16.9, 394.02, 12.43))</td><td>19.75666434415576</td></tr><tr><td>Map(vectorType -> dense, length -> 13, values -> List(0.0536, 21.0, 5.64, 0.0, 0.439, 6.511, 21.1, 6.8147, 4.0, 243.0, 16.8, 396.9, 5.28))</td><td>27 ...

# %% [markdown]
# # Random Forest

# %%
from pyspark.ml.regression import RandomForestRegressor
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# create random forest instance
rf = RandomForestRegressor(labelCol='medv')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# fit the model
rf_fit = rf.fit(train)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# generate predictions on new data
rf_fit.transform(new_data).display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>features</th><th>prediction</th></tr></thead><tbody><tr><td>Map(vectorType -> dense, length -> 13, values -> List(0.01301, 35.0, 1.52, 0.0, 0.442, 7.241, 49.3, 7.0379, 1.0, 284.0, 15.5, 394.74, 5.49))</td><td>32.487828068881015</td></tr><tr><td>Map(vectorType -> dense, length -> 13, values -> List(0.01538, 90.0, 3.75, 0.0, 0.394, 7.454, 34.2, 6.3361, 3.0, 244.0, 15.9, 386.34, 3.11))</td><td>40.205171178086616</td></tr><tr><td>Map(vectorType -> dense, length -> 13, values -> List(0.01965, 80.0, 1.76, 0.0, 0.385, 6.23, 31.5, 9.0892, 1.0, 241.0, 18.2, 341.6, 12.93))</td><td>23.85091929379118</td></tr><tr><td>Map(vectorType -> dense, length -> 13, values -> List(0.02729, 0.0, 7.07, 0.0, 0.469, 7.185, 61.1, 4.9671, 2.0, 242.0, 17.8, 392.83, 4.03))</td><td>38.18507612539966</td></tr><tr><td>Map(vectorType -> dense, length -> 13, values -> List(0.02763, 75.0, 2.95, 0.0, 0.428, 6.595, 21.8, 5.4011, 3.0, 252.0, 18.3, 395.63, 4.32))</td><td>27.99750001393778</td></tr><tr><td>Map(vectorType -> dense, length -> 13, values -> List(0.03049, 55.0, 3.78, 0.0, 0.484, 6.874, 28.1, 6.4654, 5.0, 370.0, 17.6, 387.97, 4.61))</td><td>31.338530116664884</td></tr><tr><td>Map(vectorType -> dense, length -> 13, values -> List(0.03306, 0.0, 5.19, 0.0, 0.515, 6.059, 37.3, 4.8122, 5.0, 224.0, 20.2, 396.14, 8.51))</td><td>22.06062588386747</td></tr><tr><td>Map(vectorType -> dense, length -> 13, values -> List(0.03466, 35.0, 6.06, 0.0, 0.4379, 6.031, 23.3, 6.6407, 1.0, 304.0, 16.9, 362.25, 7.83))</td><td>22.827832140107592</td></tr><tr><td>Map(vectorType -> dense, length -> 13, values -> List(0.03537, 34.0, 6.09, 0.0, 0.433, 6.59, 40.4, 5.4917, 7.0, 329.0, 16.1, 395.75, 9.5))</td><td>24.103309818785824</td></tr><tr><td>Map(vectorType -> dense, length -> 13, values -> List(0.03584, 80.0, 3.37, 0.0, 0.398, 6.29, 17.8, 6.6115, 4.0, 337.0, 16.1, 396.9, 4.67))</td><td>24.480757264738198</td></tr><tr><td>Map(vectorType -> dense, length -> 13, values -> List(0.03738, 0.0, 5.19, 0.0, 0.515, 6.31, 38.5, 6.4584, 5.0, 224.0, 20.2, 389.4, 6.75))</td><td>23.35261619913019</td></tr><tr><td>Map(vectorType -> dense, length -> 13, values -> List(0.03768, 80.0, 1.52, 0.0, 0.404, 7.274, 38.3, 7.309, 2.0, 329.0, 12.6, 392.2, 6.62))</td><td>31.64091052836053</td></tr><tr><td>Map(vectorType -> dense, length -> 13, values -> List(0.03961, 0.0, 5.19, 0.0, 0.515, 6.037, 34.5, 5.9853, 5.0, 224.0, 20.2, 396.9, 8.01))</td><td>22.16088904176221</td></tr><tr><td>Map(vectorType -> dense, length -> 13, values -> List(0.04113, 25.0, 4.86, 0.0, 0.426, 6.727, 33.5, 5.4007, 4.0, 281.0, 19.0, 396.9, 5.29))</td><td>26.57205670624095</td></tr><tr><td>Map(vectorType -> dense, length -> 13, values -> List(0.04294, 28.0, 15.04, 0.0, 0.464, 6.249, 77.3, 3.615, 4.0, 270.0, 18.2, 396.9, 10.59))</td><td>21.42664665444072</td></tr><tr><td>Map(vectorType -> dense, length -> 13, values -> List(0.04417, 70.0, 2.24, 0.0, 0.4, 6.871, 47.4, 7.8278, 5.0, 358.0, 14.8, 390.86, 6.07))</td><td>29.665981481503746</td></tr><tr><td>Map(vectorType -> dense, length -> 13, values -> List(0.0459, 52.5, 5.32, 0.0, 0.405, 6.315, 45.6, 7.3172, 6.0, 293.0, 16.6, 396.9, 7.6))</td><td>23.52420360765674</td></tr><tr><td>Map(vectorType -> dense, length -> 13, values -> List(0.04666, 80.0, 1.52, 0.0, 0.404, 7.107, 36.6, 7.309, 2.0, 329.0, 12.6, 354.31, 8.61))</td><td>30.764602369852366</td></tr><tr><td>Map(vectorType -> dense, length -> 13, values -> List(0.04932, 33.0, 2.18, 0.0, 0.472, 6.849, 70.3, 3.1827, 7.0, 222.0, 18.4, 396.9, 7.53))</td><td>29.066482540085683</td></tr><tr><td>Map(vectorType -> dense, length -> 13, values -> List(0.05023, 35.0, 6.06, 0.0, 0.4379, 5.706, 28.4, 6.6407, 1.0, 304.0, 16.9, 394.02, 12.43))</td><td>21.228439045440656</td></tr><tr><td>Map(vectorType -> dense, length -> 13, values -> List(0.0536, 21.0, 5.64, 0.0, 0.439, 6.511, 21.1, 6.8147, 4.0, 243.0, 16.8, 396.9, 5.28))</td><td>25. ...

# %%
# feature importance
rf_fit.featureImportances
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[28]: SparseVector(13, {0: 0.0645, 1: 0.0066, 2: 0.0314, 3: 0.0048, 4: 0.0576, 5: 0.3104, 6: 0.0145, 7: 0.0655, 8: 0.004, 9: 0.0249, 10: 0.0702, 11: 0.0208, 12: 0.3246})</div>

# %% [markdown]
# # Cross-Validation / Hyperparameter Tuning, etc.
#
# Read Documentation: https://spark.apache.org/docs/latest/ml-tuning.html
