# %% [markdown]
# # Hugging Face Transformers 🤗
#
# The Hugging Face transformers package is an immensely popular Python library providing pretrained models that are extraordinarily useful for a variety of natural language processing (NLP) tasks. It previously supported only PyTorch, but, as of late 2019, TensorFlow 2 is supported as well. While the library can be used for many tasks from Natural Language Inference (NLI) to Question-Answering, text classification remains one of the most popular and practical use cases.
#
# Transformers (formerly known as pytorch-transformers and pytorch-pretrained-bert) provides general-purpose architectures (BERT, GPT-2, RoBERTa, XLM, DistilBert, XLNet…) for Natural Language Understanding (NLU) and Natural Language Generation (NLG) with over 32+ pretrained models in 100+ languages and deep interoperability between Jax, PyTorch and TensorFlow.
#
# https://huggingface.co/transformers/

# %%
from transformers import pipeline

# %% [markdown]
# # Text Generation

# %%
generator = pipeline('text-generation')
# Out:
# No model was supplied, defaulted to gpt2 and revision 6c0e608 (https://huggingface.co/gpt2).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# Downloading config.json:   0%|          | 0.00/665 [00:00<?, ?B/s]
# Downloading pytorch_model.bin:   0%|          | 0.00/523M [00:00<?, ?B/s]
# Downloading vocab.json:   0%|          | 0.00/0.99M [00:00<?, ?B/s]
# Downloading merges.txt:   0%|          | 0.00/446k [00:00<?, ?B/s]
# Downloading tokenizer.json:   0%|          | 0.00/1.29M [00:00<?, ?B/s]

# %%
generator("Adam and Natalie are good friends.")
# Out:
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# /databricks/python/lib/python3.9/site-packages/transformers/generation_utils.py:1202: UserWarning: Neither `max_length` nor `max_new_tokens` have been set, `max_length` will default to 50 (`self.config.max_length`). Controlling `max_length` via the config is deprecated and `max_length` will be removed from the config in v5 of Transformers -- we recommend using `max_new_tokens` to control the maximum length of the generation.
#   warnings.warn(
# Out[3]: [{'generated_text': 'Adam and Natalie are good friends. Natalie had been married for three years before moving out. She was worried about her health and was worried for her daughter and his sister. Both Amanda and Natalie were there and Amanda was on the court record in the first'}]

# %%
generator("Since I have joined Queens University.")
# Out:
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Out[4]: [{'generated_text': 'Since I have joined Queens University.com, I am sure many thousands upon thousands of students have come home from college with a sense of excitement. In my humble opinion, the most common answer has been "It\'s too soon."\n\nAs a'}]

# %%
generator("Canada is a country.....")
# Out:
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Out[5]: [{'generated_text': 'Canada is a country.....we will only be able to make it better in a few centuries." - John Gorman\n\nSo here are the two most radical and conservative changes that have kept America from growing ever stronger. They take away our rights to'}]
