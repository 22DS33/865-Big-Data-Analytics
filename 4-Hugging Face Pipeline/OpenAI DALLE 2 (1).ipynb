# %%
import openai

# Set your API key
openai.api_key = 

# Define the text description for the image you want to generate
prompt = "photo realistic image of a professor dancing on ocean"

# Call the DALL-E 2 API to generate the image
response = openai.Image.create(prompt=prompt)

# The generated image is returned in response
print(response)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">{
#   &#34;created&#34;: 1674783343,
#   &#34;data&#34;: [
#     {
#       &#34;url&#34;: &#34;https://oaidalleapiprodscus.blob.core.windows.net/private/org-Wf88g4nXyqpFlPdLIEUo3wZ5/user-FFpU1cz5UFdb0H0VuknlF4Ji/img-UEo7guwsi6fmehrC98zapDYI.png?st=2023-01-27T00%3A35%3A43Z&amp;se=2023-01-27T02%3A35%3A43Z&amp;sp=r&amp;sv=2021-08-06&amp;sr=b&amp;rscd=inline&amp;rsct=image/png&amp;skoid=6aaadede-4fb3-4698-a8f6-684d7786b067&amp;sktid=a48cca56-e6da-484e-a814-9c849652bcb3&amp;skt=2023-01-26T23%3A30%3A56Z&amp;ske=2023-01-27T23%3A30%3A56Z&amp;sks=b&amp;skv=2021-08-06&amp;sig=rnOIJ59TmTJ%2BRObJ4IRn8ACwmGvcT1/1fr%2Bdl6NLruk%3D&#34;
#     }
# ...
